# %%
import pylab as plt
import FlowCytometryTools
from FlowCytometryTools import test_data_dir, test_data_file, FCMeasurement, FCPlate, ThresholdGate, PolyGate
from sklearn.cluster import KMeans

# %matplotlib inline

# %%
plate = FCPlate.from_dir(ID='Demo Plate', path= './CTC_FVD_Hoechst_test120315/', parser='name')
plate = plate.transform('hlog', channels=['FSC-A', 'SSC-A', 'PI (B)-A', 'Alexa Fluor 488-A', 'Pacific Blue-A'])
plate = plate.dropna()

# %%
import pylab as plt

# %%
plt.figure();

plate.plot(('PI (B)-A'), bins=100, wspace=0.2, hspace=0.2);
